# %% [markdown]
# # <center>        **Introduction to Data Science (S2-22_DSECLZG532)-ASSIGNMENT**</center>
#
# ## Group No 99
#
# ## Group Member Names:
# 1. Darshan R
# 2. Dhivya R
# 3. Divya H R
# 4. Fatheah Mohammad Ghouse R

# %% [markdown]
# # 1. Business Understanding
#
# Students are expected to identify an analytical problem of your choice. You have to detail the Business Understanding part of your problem under this heading which basically addresses the following questions.
#
#    1. What is the business problem that you are trying to solve?
#    2. What data do you need to answer the above problem?
#    3. What are the different sources of data?
#    4. What kind of analytics task are you performing?
#
# Score: 1 Mark in total (0.25 mark each)

# %% [raw]
# # Airline Passenger Satisfaction Project
#
# ## Overview
#
# This project focuses on analyzing a dataset derived from an airline passenger satisfaction survey with the aim of identifying key factors influencing customer satisfaction within the airline industry. The satisfaction metric plays a crucial role for businesses, especially in the airline sector, where understanding and managing customer satisfaction is essential for delivering high-quality services that meet customer expectations.
#
# ## Objectives
#
# - **Determine Customer Satisfaction Factors:** Investigate and determine the factors that significantly contribute to customer satisfaction.
# - **Quality Improvement:** Explore insights from the survey data to guide improvements and ensure a higher quality of service delivery.
#
# ## Dataset Features
#
# The dataset encompasses various types of features, including:
#
# ### Survey Features
# - Features measured on a 5-point Likert scale:
#   - Food and drink
#   - Seat comfort
#   - Inflight entertainment
#
# ### Demographic Features
# - Age
# - Gender
#
# ### Commercial Features
# - Customer Type
#
# Understanding the interplay of these features and their impact on customer satisfaction is vital for enhancing the overall customer experience in the airline industry.

# %% [markdown]
# # 2. Data Acquisition
#
# For the problem identified , find an appropriate data set (Your data set must
# be unique with minimum **20 features and 10k rows**) from any public data source.
#
# ---
#
#
#
# ## 2.1 Download the data directly

# %%
# !wget  "https://raw.githubusercontent.com/ghousiee/airline_satisfaction_analysis/main/dataset.csv"
# Out:
# --2024-03-12 11:58:32--  https://raw.githubusercontent.com/ghousiee/airline_satisfaction_analysis/main/dataset.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12193089 (12M) [text/plain]
# Saving to: ‘dataset.csv’
#
# dataset.csv         100%[===================>]  11.63M  --.-KB/s    in 0.1s
#
# 2024-03-12 11:58:32 (114 MB/s) - ‘dataset.csv’ saved [12193089/12193089]

# %% [markdown]
# ## 2.2 Code for converting the above downloaded data into a dataframe

# %%
import pandas as pd
df = pd.read_csv("/content/dataset.csv")
df = df.drop(['Unnamed: 0','id'], axis=1)

# %% [markdown]
# ## 2.3 Confirm the data has been correctly by displaying the first 5 and last 5 records.

# %%
df.head(5)
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %%
df.tail()
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 103899              192                      2
# 103900             2347                      4
# 103901             1995                      1
# 103902             1000                      1
# 103903             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 103899                                  1                       2
# 103900                                  4                       4
# 103901                                  1                       1
# ...

# %% [markdown]
# ## 2.4 Display the column headings, statistical information, description and statistical summary of the data.

# %%
# Column headings
df.columns.to_list()
# Out:
# ['Gender',
#  'Customer Type',
#  'Age',
#  'Type of Travel',
#  'Class',
#  'Flight Distance',
#  'Inflight wifi service',
#  'Departure/Arrival time convenient',
#  'Ease of Online booking',
#  'Gate location',
#  'Food and drink',
#  'Online boarding',
#  'Seat comfort',
#  'Inflight entertainment',
#  'On-board service',
#  'Leg room service',
#  'Baggage handling',
#  'Checkin service',
#  'Inflight service',
#  'Cleanliness',
#  'Departure Delay in Minutes',
#  'Arrival Delay in Minutes',
#  'satisfaction']

# %%
# Statistical Information
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  object
#  1   Customer Type                      103904 non-null  object
#  2   Age                                103904 non-null  int64
#  3   Type of Travel                     103904 non-null  object
#  4   Class                              103904 non-null  object
#  5   Flight Distance                    103904 non-null  int64
#  6   Inflight wifi service              103904 non-null  int64
#  7   Departure/Arrival time convenient  103904 non-null  int64
#  8   Ease of Online booking             103904 non-null  int64
#  9   Gate location                      103904 non-null  int64
#  10  Food and drink                     103904 non-null  int64
# ...

# %%
# Description
df.describe()
# Out:
#                  Age  Flight Distance  Inflight wifi service  \
# count  103904.000000    103904.000000          103904.000000
# mean       39.379706      1189.448375               2.729683
# std        15.114964       997.147281               1.327829
# min         7.000000        31.000000               0.000000
# 25%        27.000000       414.000000               2.000000
# 50%        40.000000       843.000000               3.000000
# 75%        51.000000      1743.000000               4.000000
# max        85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      103904.000000           103904.000000
# mean                            3.060296                2.756901
# std                             1.525075                1.398929
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# ...

# %%
# Statistical Summary
for column in df.select_dtypes(include='object').columns:
    print(f"\n{column}:\n{df[column].value_counts()}")
# Out:
# Gender:
# Female    52727
# Male      51177
# Name: Gender, dtype: int64
#
# Customer Type:
# Loyal Customer       84923
# disloyal Customer    18981
# Name: Customer Type, dtype: int64
#
# Type of Travel:
# Business travel    71655
# Personal Travel    32249
# Name: Type of Travel, dtype: int64
#
# Class:
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: Class, dtype: int64
#
# satisfaction:
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: satisfaction, dtype: int64

# %% [markdown]
# ## 2.5 Write your observations from the above.
# 1. Size of the dataset
# 2. What type of data attributes are there?
# 3. Is there any null data that has to be cleaned?
#
# Score: 2 Marks in total (0.25 marks for 2.1, 0.25 marks for 2.2, 0.5 marks for 2.3, 0.25 marks for 2.4, 0.75 marks for 2.5)

# %%
print("Size of the dataset is",df.size) # size = df.shape[0] * df.shape[1]
print(f"Shape of the dataset\nRows: {df.shape[0]}\nColumns: {df.shape[1]}")
# Out:
# Size of the dataset is 2389792
# Shape of the dataset
# Rows: 103904
# Columns: 23

# %%
print(f"Unique values")
for column in df.columns:
  print(f"{column} is {len(df[column].unique())}")
# Out:
# Unique values
# Gender is 2
# Customer Type is 2
# Age is 75
# Type of Travel is 2
# Class is 3
# Flight Distance is 3802
# Inflight wifi service is 6
# Departure/Arrival time convenient is 6
# Ease of Online booking is 6
# Gate location is 6
# Food and drink is 6
# Online boarding is 6
# Seat comfort is 6
# Inflight entertainment is 6
# On-board service is 6
# Leg room service is 6
# Baggage handling is 5
# Checkin service is 6
# Inflight service is 6
# Cleanliness is 6
# Departure Delay in Minutes is 446
# Arrival Delay in Minutes is 456
# satisfaction is 2

# %% [markdown]
# ## Types of data attributes
# ### Qualitative Data:
# #### Nominal:
# - Gender
# - Customer Type
# - Type of Travel
# - Class
# - Satisfaction
#
# #### Ordinal:
# - Inflight wifi service
# - Departure/Arrival time convenient
# - Ease of Online booking
# - Gate location
# - Food and drink
# - Online boarding
# - Seat comfort
# - Inflight entertainment
# - On-board service
# - Leg room service
# - Baggage handling
# - Checkin service
# - Inflight service
# - Cleanliness
#
# ### Quantitative Data:
#
# #### Numeric:
# - Age
# - Flight Distance
# - Departure Delay in Minutes
# - Arrival Delay in Minutes

# %%
df.isna().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# ...

# %% [markdown]
# There is 310 null values in column `Arrival Delay in Minutes` that needs to be cleaned

# %% [markdown]
# # 3. Data Preparation

# %% [raw]
# If input data is numerical or categorical, do 3.1, 3.2 and 3.4
# If input data is text, do 3.3 and 3.4

# %% [markdown]
# ## 3.1 Check for
#
# * duplicate data
# * missing data
# * data inconsistencies

# %% [markdown]
# Checking duplicates

# %%
print(f"There are {df.duplicated().sum()} duplicates found in the dataset")
# Out:
# There are 0 duplicates found in the dataset

# %% [markdown]
# Checking missing data

# %%
missing_data_per_column = df.isnull().sum()

print("Missing Data per Column:")
print(missing_data_per_column)
# Out:
# Missing Data per Column:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# ...

# %% [markdown]
# Checking data inconsistencies

# %%
for column in df.select_dtypes(include='object').columns:
    print(f"\n{column} Value Counts:\n{df[column].value_counts()}")
# Out:
# Gender Value Counts:
# Female    52727
# Male      51177
# Name: Gender, dtype: int64
#
# Customer Type Value Counts:
# Loyal Customer       84923
# disloyal Customer    18981
# Name: Customer Type, dtype: int64
#
# Type of Travel Value Counts:
# Business travel    71655
# Personal Travel    32249
# Name: Type of Travel, dtype: int64
#
# Class Value Counts:
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: Class, dtype: int64
#
# satisfaction Value Counts:
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: satisfaction, dtype: int64

# %%
print("\nData Types:")
print(df.dtypes)
# Out:
# Data Types:
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# ...

# %% [markdown]
# ## 3.2 Apply techiniques
# * to remove duplicate data
# * to impute or remove missing data
# * to remove data inconsistencies

# %% [markdown]
# #### Applying
# - No duplicates and no inconsistency present in the data.
# - Imputed missing values with mean.

# %%
arrival_mean = df['Arrival Delay in Minutes'].mean()
df['Arrival Delay in Minutes'] = df['Arrival Delay in Minutes'].fillna(arrival_mean)

# %% [markdown]
# ## 3.3 Encode categorical data

# %%
nominal_attributes = ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']
ordinal_attributes = ['Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking',
                      'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort', 'Inflight entertainment',
                      'On-board service', 'Leg room service', 'Baggage handling', 'Checkin service', 'Inflight service',
                      'Cleanliness']

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
for column in nominal_attributes:
  df[column] = label_encoder.fit_transform(df[column])

# %%
df[nominal_attributes].sample(5)
# Out:
#        Gender  Customer Type  Type of Travel  Class  satisfaction
# 85431       0              1               0      1             0
# 96988       0              0               0      0             1
# 43984       0              0               0      0             1
# 21572       1              0               0      0             1
# 42111       1              0               0      0             1

# %%
df[ordinal_attributes].sample(5)
# Out:
#         Inflight wifi service  Departure/Arrival time convenient  \
# 61953                       3                                  3
# 22159                       3                                  3
# 26798                       1                                  5
# 101909                      5                                  5
# 67405                       1                                  4
#
#         Ease of Online booking  Gate location  Food and drink  \
# 61953                        3              3               3
# 22159                        3              2               1
# 26798                        4              5               5
# 101909                       5              5               4
# 67405                        1              1               3
#
#         Online boarding  Seat comfort  Inflight entertainment  \
# 61953                 3             3                       3
# 22159                 3             1                       1
# ...

# %%
##---------Type the code below this line------------------##

# %% [markdown]
# ## 3.4 Report
#
# Mention and justify the method adopted
# * to remove duplicate data, if present
# * to impute or remove missing data, if present
# * to remove data inconsistencies, if present
#
# OR for textdata
# * How many tokens after step 3?
# * how may tokens after stop words filtering?
#
# If the any of the above are not present, then also add in the report below.
#
# Score: 2 Marks (based on the dataset you have, the data prepreation you had to do and report typed, marks will be distributed between 3.1, 3.2, 3.3 and 3.4)

# %% [markdown]
# ## Report
#
# ### Removal of Duplicate Data
#
# No duplicate data was identified in the dataset.
#
# ### Handling Missing Data
#
# Upon inspection, it was observed that the attribute `Arrival Delay in Minutes` had 310 missing values. Instead of opting for removal, a decision was made to impute the missing values with the mean of the column. This choice was motivated by the desire to preserve the information from other columns associated with the respective records.
#
# ### Addressing Data Inconsistencies
#
# The dataset did not exhibit any evidence for data inconsistencies.

# %% [markdown]
# ## 3.5 Identify the target variables.
#
# * Separate the data from the target such that the dataset is in the form of (X,y) or (Features, Label)
#
# * Discretize / Encode the target variable or perform one-hot encoding on the target or any other as and if required.
#
# * Report the observations
#
# Score: 1 Mark

# %%
# df = df.drop('id', axis=1).copy()

# %%
X = df.drop(['satisfaction'], axis=1)
y = df['satisfaction']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=70)

# %% [markdown]
# # 4. Data Exploration using various plots

# %% [markdown]
# ## 4.1 Scatter plot of each quantitative attribute with the target.
#
# Score: 1 Mark

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
numeric_attributes = ['Age','Flight Distance','Departure Delay in Minutes','Arrival Delay in Minutes']
# df[numeric_attributes]

# %%
sns.set(style="whitegrid")

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))

for i, attribute in enumerate(numeric_attributes):
    row = i // 2
    col = i % 2
    sns.scatterplot(x=df[attribute], y=y, marker='o', color='blue', ax=axes[row, col])
    axes[row, col].set_title(f"Scatter Plot: {attribute} vs. Target")
    axes[row, col].set_xlabel(attribute)
    axes[row, col].set_ylabel('Target')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
sns.scatterplot(x='Departure Delay in Minutes',y='Arrival Delay in Minutes', hue= 'satisfaction', data=df)
# Out:
# <Axes: xlabel='Departure Delay in Minutes', ylabel='Arrival Delay in Minutes'>

# %% [markdown]
# ## 4.2 EDA using visuals
# * Use (minimum) 2 plots (pair plot, heat map, correlation plot, regression plot...) to identify the optimal set of attributes that can be used for classification.
# * Name them, explain why you think they can be helpful in the task and perform the plot as well. Unless proper justification for the choice of plots given, no credit will be awarded.
#
# Score: 2 Marks

# %%
# Box plot
plt.figure(figsize=(6, 4))
sns.boxplot(x='satisfaction', y='Age', data=df)
plt.title('Box Plot of Age by satisfaction')
plt.xlabel('satisfaction')
plt.ylabel('Age')
plt.show()

# Violin plot
plt.figure(figsize=(6, 4))
sns.violinplot(x='satisfaction', y='Age', data=df)
plt.title('Violin Plot of Age by satisfaction')
plt.xlabel('satisfaction')
plt.ylabel('Age')
plt.show()

# %%
df[nominal_attributes]
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction
# 0            1              0               1      2             0
# 1            1              1               0      0             0
# 2            0              0               0      0             1
# 3            0              0               0      0             0
# 4            1              0               0      0             1
# ...        ...            ...             ...    ...           ...
# 103899       0              1               0      1             0
# 103900       1              0               0      0             1
# 103901       1              1               0      0             0
# 103902       0              1               0      1             0
# 103903       1              0               0      0             0
#
# [103904 rows x 5 columns]

# %%
plt.style.use('seaborn-white')
sns.set_palette('Paired')


fig = plt.figure(figsize=(12,12))

cols = df[nominal_attributes].columns.tolist()
cols.remove('satisfaction')

for ind,col in enumerate(cols):

    plt.subplot(3,2,ind+1)
    g = sns.countplot(data=df,x=col,hue='satisfaction')
    g.set_xlabel('')
    g.set_ylabel('')
    g.set_title(col)

fig.suptitle("Satisfaction vs Categories",size=15)
fig.tight_layout()
plt.show()
# Out:
# <ipython-input-33-94355c8e420f>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %%
import numpy as np

plt.figure(figsize=(10, 6))
mask = np.triu(np.ones_like(df.corr()))

# plotting a triangle correlation heatmap
dataplot = sns.heatmap(df.corr(), mask=mask,cmap="YlGnBu",)
plt.show()

# %%
sns.pairplot(df)

# %% [markdown]
# # 5. Data Wrangling

# %% [markdown]
# ## 5.1 Univariate Filters
#
# #### Numerical and Categorical Data
# * Identify top 5 significant features by evaluating each feature independently with respect to the target/other variable by exploring
# 1. Mutual Information (Information Gain)
# 2. Gini index
# 3. Gain Ratio
# 4. Chi-Squared test
# 5. Strenth of Association
#
# (From the above 5 you are required to use only any <b>two</b>)
#
#
#
# Score: 3 Marks

# %%
from sklearn.feature_selection import mutual_info_classif, chi2
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest, f_classif


# Separate numerical and categorical columns
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns

# Feature selection for categorical data using Chi-Squared
chi2_values, _ = chi2(df[nominal_attributes], df['satisfaction'])
categorical_features_chi2 = pd.Series(chi2_values, index=nominal_attributes).sort_values(ascending=False).head(5)

# Feature selection for numerical and categorical data using RandomForest feature importance
rf_classifier = RandomForestClassifier()
rf_classifier.fit(df[numerical_columns].fillna(0), df['satisfaction'])
numerical_features_rf_importance = pd.Series(rf_classifier.feature_importances_, index=numerical_columns).sort_values(ascending=False).head(5)


print("\nTop 5 Categorical Features by Chi-Squared:")
print(categorical_features_chi2)

print("\nTop 5 Numerical Features by RandomForest Feature Importance:")
print(numerical_features_rf_importance)
# Out:
# Top 5 Categorical Features by Chi-Squared:
# satisfaction      58879.000000
# Type of Travel    14445.748601
# Class             13606.876336
# Customer Type      2989.976064
# Gender                7.862399
# dtype: float64
#
# Top 5 Numerical Features by RandomForest Feature Importance:
# satisfaction             0.558207
# Online boarding          0.101949
# Type of Travel           0.064002
# Inflight wifi service    0.053594
# Class                    0.044596
# dtype: float64

# %% [markdown]
# ## 5.2 Report observations
#
# Write your observations from the results of each method. Clearly justify your choice of the method.
#
# Score 1 mark

# %% [markdown]
# ## Observations and Recommendations for Feature Selection
#
# ### Categorical Features by Chi-Squared:
#
# - The categorical feature with the highest Chi-Squared score is 'satisfaction,' likely the target variable, as expected due to its strong association with itself.
# - Other important categorical features include 'Type of Travel,' 'Class,' 'Customer Type,' and 'Gender.'
# - Chi-Squared is suitable for identifying associations between nominal categorical features and the target variable.
#
# ### Numerical Features by Random Forest Feature Importance:
#
# - The most important numerical feature according to Random Forest is 'satisfaction,' again likely the target variable.
# - Other top numerical features are 'Online boarding,' 'Inflight wifi service,' 'Class,' and 'Type of Travel.'
# - Random Forest captures non-linear relationships and interactions, making it powerful for feature importance estimation.
#
# ### Choice of Method:
#
# Based on these observations, **Random Forest Feature Importance** is recommended for feature selection due to the following reasons:
#
# 1. **Non-linearity and Interactions:**
#    - Random Forest can capture non-linear relationships and feature interactions, addressing complexities that univariate methods may miss.
#
# 2. **Numerical and Categorical Features:**
#    - Random Forest handles both numerical and categorical features seamlessly, offering a unified approach to feature selection.
#
# 3. **Feature Importance Interpretation:**
#    - The feature importance scores from Random Forest are interpretable and directly applicable for feature selection or engineering.
#
# 4. **Robustness:**
#    - Random Forest is generally robust to multicollinearity and outliers, enhancing its reliability for feature selection.

# %% [markdown]
# # 6. Implement Machine Learning Techniques
#
# Use any 2 ML tasks
# 1. Classification
#
# 2. Clustering
#
# 3. Association Analysis
#
# 4. Anomaly detection
#
# You may use algorithms included in the course, e.g. Decision Tree, K-means etc. or an algorithm you learnt on your own with a brief explanation.
# A clear justification have to be given for why a certain algorithm was chosen to address your problem.
#
# Score: 4 Marks (2 marks each for each algorithm)

# %% [markdown]
# ## 6.1 ML technique 1 + Justification

# %% [markdown]
# # Decision Tree Classifier
#
# ## Interpretability
# Decision Trees are known for their relative ease of interpretation, providing a hierarchical structure that unveils decision rules and factors influencing passenger satisfaction. This transparency facilitates a clear understanding of the model's decision-making process, aiding in the identification of areas for improvement and providing valuable insights to stakeholders.
#
# ## Non-linear Relationships
# Decision Trees excel in capturing non-linear relationships between features and the target variable (satisfaction). In real-world scenarios, such as passenger satisfaction data, where relationships may not follow a linear pattern, Decision Trees offer the flexibility to model complex interactions.
#
# ## Feature Importance
# A notable feature of Decision Trees is their built-in mechanism for estimating the importance of each feature. This capability allows for the identification of key factors contributing to passenger satisfaction. By assessing feature importance, analysts can prioritize areas for further investigation or improvement.
#
# ## Handling Mixed Data Types
# Decision Trees possess the ability to handle both numerical and categorical features natively. This eliminates the need for extensive feature engineering or encoding, streamlining the preprocessing steps. The inherent versatility in handling mixed data types makes Decision Trees well-suited for datasets with diverse feature types, such as those encountered in airline passenger satisfaction projects.

# %%
labels = ["neutral or dissatisfied", "satisfied"]
metrics_df = pd.DataFrame(columns=['TN', 'TP', 'FN', 'FP', 'Pos_Precision', 'Pos_Recall', 'Pos_F1','ROC AUC'],
                          index=['DecisionTree', 'RandomForest'])
metrics_df
# Out:
#                TN   TP   FN   FP Pos_Precision Pos_Recall Pos_F1 ROC AUC
# DecisionTree  NaN  NaN  NaN  NaN           NaN        NaN    NaN     NaN
# RandomForest  NaN  NaN  NaN  NaN           NaN        NaN    NaN     NaN

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,stratify=y, random_state=70)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn import datasets


dt_clf = DecisionTreeClassifier(random_state=42)
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# ## 6.2 ML technique 2 + Justification

# %% [markdown]
# # Random Forest Classifier
#
# ## Ensemble Learning
# Random Forests employ ensemble learning by combining multiple decision trees. This approach often leads to improved predictive performance and reduced overfitting compared to using a single decision tree. The ensemble nature of Random Forests enhances the model's ability to generalize well to diverse datasets.
#
# ## Non-linear Relationships and Feature Interactions
# Random Forests excel at capturing non-linear relationships and interactions between features and the target variable (passenger satisfaction). This capability is crucial for modeling the intricate dynamics inherent in passenger satisfaction data, where the relationships may not follow a simple linear pattern.
#
# ## Robustness to Outliers and Noise
# Random Forests exhibit robustness to outliers and noise in the data, a valuable characteristic when dealing with real-world datasets such as airline passenger data. This robustness contributes to the model's stability and reliability in the presence of data variations.
#
# ## Feature Importance
# Similar to Decision Trees, Random Forests provide a built-in mechanism to estimate the importance of each feature. This feature importance analysis aids in identifying the key factors influencing passenger satisfaction, providing valuable insights for decision-making and model interpretation.
#
# ## Parallelization and Scalability
# Random Forests can be parallelized, allowing for efficient computation and scalability. This characteristic is beneficial for handling large datasets, making Random Forests suitable for scenarios where scalability is essential, as may be the case with airline passenger data.

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
random_forest_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# ## 7. Conclusion
#
# Compare the performance of the ML techniques used.
#
# Derive values for preformance study metrics like accuracy, precision, recall, F1 Score, AUC-ROC etc to compare the ML algos and plot them. A proper comparision based on different metrics should be done and not just accuracy alone, only then the comparision becomes authentic. You may use Confusion matrix, classification report, Word cloud etc as per the requirement of your application/problem.
#
# Score 1 Mark

# %%
import itertools
from collections import Counter

def roc_curve_function(fpr, tpr):

    plt.figure(figsize=(10,6))

    plt.title('ROC Curve', fontsize=16)

    plt.plot([0, 1], [0, 1], 'r--')
    plt.plot(fpr, tpr, 'b-', linewidth=2)

    plt.xlabel('False Positive Rate', fontsize=16)
    plt.ylabel('True Positive Rate', fontsize=16)
    plt.axis([-0.01,1,0,1])



def plot_confusion_matrix_function(cm, classes,normalize=False,
                          title='Confusion matrix',cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=14)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    plt.show()

def custom_classification_metrics_function(X_test, y_test, labels, classifier, data_type='Test', output_metrics=False):

    ### Plain old accuracy
    test_score = classifier.score(X_test, y_test)

    # change the floating point representation
    test_accuracy = float("{0:.2f}".format(test_score.mean()))
    print("Has a {} accuracy of {} % ".format(data_type, test_accuracy * 100))

    ### Classification report
    test_pred = classifier.predict(X_test)

    print(classification_report(y_test, test_pred, target_names=labels))

    ### ROC AUC score
    # Only store the 2nd column which corresponds to the probability for the positive class
    y_scores = classifier.predict_proba(X_test)[:, 1]

    # change the floating point representation
    roc_auc_val = float("{0:.2f}".format(roc_auc_score(y_test, y_scores)))
    print('The ROC AUC Score on {} set is {}'.format(data_type, roc_auc_val))

    ### ROC AUC Curve
    fpr, tpr, threshold = roc_curve(y_test, test_pred)
    roc_curve_function(fpr, tpr)

    ### Confusion Matrix
    confusion_matrix_test_object = confusion_matrix(y_test, test_pred)

    fig = plt.figure(figsize=(8,4))
    plot_confusion_matrix_function(confusion_matrix_test_object,
                                   labels, title= data_type + ' ' + "Confusion Matrix", cmap=plt.cm.Oranges)

    ### Output metrics (optional)
    if output_metrics:

        # Initialize a dictionary to store the 8 metrics we are interested in
        metrics_dict = Counter()

        # Metrics from the confusion matrix
        metrics_dict['TN'] = confusion_matrix_test_object[0][0]
        metrics_dict['TP'] = confusion_matrix_test_object[1][1]
        metrics_dict['FN'] = confusion_matrix_test_object[1][0]
        metrics_dict['FP'] = confusion_matrix_test_object[0][1]

        # Metrics from the classification report
        # We are only interested in the minority class which is 1
        metrics_dict['Pos_Precision'] = classification_report(y_test, test_pred, output_dict=True)['1']['precision']
        metrics_dict['Pos_Recall'] = classification_report(y_test, test_pred, output_dict=True)['1']['recall']
        metrics_dict['Pos_F1'] = classification_report(y_test, test_pred, output_dict=True)['1']['f1-score']

        # Metric from the ROC AUC curve
        metrics_dict['ROC AUC'] = roc_auc_val

        return metrics_dict

def update_metrics(df,model_type, metrics):
    for column in df.columns:
        df.loc[model_type][column] = metrics[column]

# %%
dt_metrics = custom_classification_metrics_function(
        X_test, y_test, labels, dt_clf, data_type='Test', output_metrics = True)
update_metrics(metrics_df,'DecisionTree', dt_metrics)
# Out:
# Has a Test accuracy of 94.0 %
#                          precision    recall  f1-score   support
#
# neutral or dissatisfied       0.95      0.95      0.95     17664
#               satisfied       0.93      0.94      0.94     13508
#
#                accuracy                           0.94     31172
#               macro avg       0.94      0.94      0.94     31172
#            weighted avg       0.94      0.94      0.94     31172
#
# The ROC AUC Score on Test set is 0.94
# Confusion matrix, without normalization
# [[16767   897]
#  [  829 12679]]

# %%
rf_metrics = custom_classification_metrics_function(
        X_test, y_test, labels, random_forest_classifier, data_type='Test', output_metrics = True)
# Out:
# Has a Test accuracy of 96.0 %
#                          precision    recall  f1-score   support
#
# neutral or dissatisfied       0.95      0.98      0.97     17664
#               satisfied       0.97      0.94      0.95     13508
#
#                accuracy                           0.96     31172
#               macro avg       0.96      0.96      0.96     31172
#            weighted avg       0.96      0.96      0.96     31172
#
# The ROC AUC Score on Test set is 0.99
# Confusion matrix, without normalization
# [[17277   387]
#  [  830 12678]]

# %%
update_metrics(metrics_df,'RandomForest', rf_metrics)

# %%
metrics_df
# Out:
#                  TN     TP   FN   FP Pos_Precision Pos_Recall    Pos_F1  \
# DecisionTree  16767  12679  829  897      0.933928   0.938629  0.936272
# RandomForest  17277  12678  830  387      0.970379   0.938555  0.954202
#
#              ROC AUC
# DecisionTree    0.94
# RandomForest    0.99

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
labels = ['Decision Tree', 'Random Forest']
tn = [16767, 17277]
tp = [12679, 12678]
fn = [829, 830]
fp = [897, 387]
precision = [0.933928, 0.970379]
recall = [0.938629, 0.938555]
f1 = [0.936272, 0.954202]
roc_auc = [0.94, 0.99]

x = np.arange(len(labels))
width = 0.35

# Bar plots
fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width/2, precision, width, label='Precision')
rects2 = ax.bar(x + width/2, recall, width, label='Recall')

# Adding labels, title, and legend
ax.set_ylabel('Scores')
ax.set_title('Precision and Recall Comparison - Decision Tree vs. Random Forest')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# Display the plot
plt.show()

# %% [markdown]
# # Model Comparison and Decision
#
# ## Observations:
#
# 1. **True Negatives (TN) and True Positives (TP):**
#    - Random Forest outperforms Decision Tree in both TN and TP, indicating better accuracy in correctly predicting both negative and positive instances.
#
# 2. **False Negatives (FN) and False Positives (FP):**
#    - Random Forest has a slightly higher FN but significantly reduces FP compared to the Decision Tree, demonstrating better precision and fewer false positive predictions.
#
# 3. **Positive Precision:**9
#    - Random Forest achieves a higher positive precision, indicating a better accuracy of positive predictions compared to the Decision Tree.
#
# 4. **Positive Recall:**
#    - Both classifiers have similar positive recall values (around 0.939), indicating a comparable ability to correctly identify positive instances.
#
# 5. **Positive F1 Score:**
#    - Random Forest achieves a higher positive F1 score, indicating a better balance between precision and recall for positive instances.
#
# 6. **ROC AUC:**
#    - Random Forest demonstrates a substantially higher ROC AUC, indicating better discrimination ability and overall model performance.
#
# ## Decision:
#
# Based on the observations, the Random Forest classifier generally outperforms the Decision Tree in terms of accuracy, precision, and ROC AUC. Therefore, the decision may favor using the Random Forest classifier for predicting passenger satisfaction in the Airline Passenger Satisfaction Project.

# %% [markdown]
# ## 8. Solution
#
# What is the solution that is proposed to solve the business problem discussed in Section 1. Also share your learnings while working through solving the problem in terms of challenges, observations, decisions made etc.
#
# Score 2 Marks

# %% [raw]
# # Proposed Solution:
# # Data Acquisition:
#
# - Acquired a dataset containing survey responses, demographic information, and commercial details related to passenger satisfaction.
#
# # Data Preparation:
#
# - Preprocessed the dataset by handling missing values, encoding categorical variables, and ensuring data consistency.
#
# # Data Exploration:
#
# - Explored the dataset to understand feature distributions, correlations, and potential patterns related to customer satisfaction.
#
# # Data Wrangling:
#
# - Conducted data wrangling to transform and clean the dataset for machine learning model implementation.
#
# # Implementing ML Techniques:
#
# - Utilized machine learning techniques, including Decision Trees and Random Forests, to predict and understand the factors influencing customer satisfaction.
#
# # Model Comparison and Decision:
#
# - Compared the performance of Decision Trees and Random Forests based on metrics such as accuracy, precision, recall, F1 score, and ROC AUC.
# - Concluded that the Random Forest classifier generally outperforms the Decision Tree in terms of accuracy and precision, making it a preferred choice for predicting customer satisfaction.
#
# # Learnings and Insights:
#
# ## Feature Importance:
#
# - Identified key features contributing to customer satisfaction, such as online boarding, inflight wifi service, and travel class.
#
# ## Challenges:
#
# - Dealing with missing data, ensuring feature consistency, and optimizing model performance were challenges faced during data preparation and ML implementation.
#
# ## Decisions Made:
#
# - Chose Random Forests over Decision Trees for better predictive performance.
# - Imputed missing values and conducted feature encoding to enhance model accuracy.
#
# # Conclusion:
#
# The project's solution involves leveraging machine learning techniques to gain insights into customer satisfaction factors and guide quality improvements. Challenges in data preparation were overcome, and decisions made during the ML process were based on model performance evaluations. The Random Forest classifier emerged as a preferred choice for predicting customer satisfaction in the airline industry. The findings provide valuable insights for airlines seeking to enhance the overall passenger experience.
